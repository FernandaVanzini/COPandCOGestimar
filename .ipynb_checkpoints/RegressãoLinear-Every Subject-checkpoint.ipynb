# %% [markdown]
# # COP and COG estimation by linear regression
# Trying to estimate COP and COG were used linear function wich didn't give the results expected, therefore we tried to make different approaches and one of them is the linear regression

# %% [markdown]
# ## Python libraries
#
# First, let's import the necessary Python libraries and configure the environment:

# %%
import numpy as np
#from scipy.signal import butter, filtfilt
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
#import seaborn as sns
#sns.set_context("notebook", font_scale=1.3,
 #               rc={'lines.linewidth': 1.5, 'lines.markersize': 14, 'axes.titlesize': 'x-large'})
#matplotlib.rc('legend', numpoints=1, fontsize=14)
#import glob
import sys, os
sys.path.insert(1, r'./Functions')
# IPython widgets:
from IPython.display import display
import ipywidgets
from ipywidgets import FloatProgress, interactive

# %% [markdown]
# Versions of the Python libraries used:

# %%
#!pip install version_information
# %load_ext version_information
# %version_information numpy, scipy, pandas, matplotlib, seaborn
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# Software versions
# Python 3.8.8 64bit [MSC v.1916 64 bit (AMD64)]
# IPython 7.22.0
# OS Windows 10 10.0.22000 SP0
# numpy 1.20.1
# scipy 1.6.2
# pandas 1.2.4
# matplotlib 3.3.4
# seaborn 0.11.1
# Wed Dec 22 17:42:57 2021 Hora oficial do Brasil

# %% [markdown]
# ## Meta data
#
# The file `PDSinfo.txt` contains meta data about the subjects and the experimental trials. The file has a header plus 588 rows per 29 columns (there are 12 rows for each of the 49 subjects).
# Let's use the power of the [pandas](http://pandas.pydata.org/) library to load and explore the meta data:

# %%
# GitHub URL:
#path2 = 'C:\Users\ferna\Downloads\IC- dados\Dados'
# local directory:
path2 = r'C:\\Users\\ferna\\Downloads\\IC- dados\\Dados'
fname = os.path.join(path2, 'PDSinfo.txt')
PDSinfo = pd.read_csv(fname, sep='\t', header=0, index_col=None, engine='c', encoding='utf-8')
print(fname)
print("Information of %s subjects loaded (%s rows, %s columns)."
      %(len(pd.unique(PDSinfo.Subject)), PDSinfo.shape[0], PDSinfo.shape[1]))
PDSinfo[PDSinfo["Subject"]==49]
# Out:
# C:\\Users\\ferna\\Downloads\\IC- dados\\Dados\PDSinfo.txt
# Information of 49 subjects loaded (588 rows, 29 columns).
#         Trial  Subject  Vision Surface  Rep    Age AgeGroup Gender  Height  \
# 576  PDS49OR1       49    Open   Rigid    1  64.92      Old      F    1.58
# 577  PDS49OR2       49    Open   Rigid    2  64.92      Old      F    1.58
# 578  PDS49OR3       49    Open   Rigid    3  64.92      Old      F    1.58
# 579  PDS49OF1       49    Open    Foam    1  64.92      Old      F    1.58
# 580  PDS49OF2       49    Open    Foam    2  64.92      Old      F    1.58
# 581  PDS49OF3       49    Open    Foam    3  64.92      Old      F    1.58
# 582  PDS49CR1       49  Closed   Rigid    1  64.92      Old      F    1.58
# 583  PDS49CR2       49  Closed   Rigid    2  64.92      Old      F    1.58
# 584  PDS49CR3       49  Closed   Rigid    3  64.92      Old      F    1.58
# 585  PDS49CF1       49  Closed    Foam    1  64.92      Old      F    1.58
# 586  PDS49CF2       49  Closed    Foam    2  64.92      Old      F    1.58
# 587  PDS49CF3       49  Closed    Foam    3  64.92      Old      F    1.58
#
#       Mass  ...  Nmedication  \
# 576  60.75  ...            3
# 577  60.75  ...            3
# 578  60.75  ...            3
# 579  60.75  ...            3
# 580  60.75  ...            3
# 581  60.75  ...            3
# 582  60.75  ...            3
# 583  60.75  ...            3
# 584  60.75  ...            3
# 585  60.75  ...            3
# 586  60.75  ...            3
# 587  60.75  ...            3
#
#                                             Medication Ortho-Prosthesis  \
# 576  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 577  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 578  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 579  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 580  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 581  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 582  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 583  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 584  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 585  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 586  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
# 587  HMG-CoA reductase inhibitor, Synthetic thyroid...              Yes
#
#                    Ortho-Prosthesis2 Disability         Disability2 Falls12m  \
# 576  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 577  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 578  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 579  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 580  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 581  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 582  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 583  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 584  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 585  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 586  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
# 587  Corrective lens, Dental implant        Yes  Hearing (Left ear)        0
#
#     PhysicalActivity        Sequence                     Date
# 576                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 577                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 578                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 579                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 580                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 581                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 582                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 583                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 584                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 585                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 586                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
# 587                0  CF, OF, CR, OR  2016-12-06 09:33:45.819
#
# [12 rows x 29 columns]

# %% [markdown]
# Here are the first 12 rows and first 10 columns of meta data:

# %% [markdown]
# ## COP and COG displacements

# %%
#trial=PDSinfo.loc[586]
re=PDSinfo.loc[PDSinfo['Subject']==49]
#print(trial['Trial'])
#print(trial['Subject'])
trial=re['Trial']
print(trial[1:2])
# Out:
# 577    PDS49OR2
# Name: Trial, dtype: object

# %% [markdown]
# ### First is necessary to take data for trial 150

# %%
for s in range(1,50):
    a=PDSinfo[PDSinfo['Subject']==s].index.tolist()[0]
    fname_grf=os.path.join(path2, PDSinfo.Trial[a]+'grf'+'.txt')
    fname_mkr=os.path.join(path2,PDSinfo.Trial[a]+'mkr'+'.txt')
    grf=pd.read_csv(fname_grf,delimiter='\t',header=0,engine='c')
    mkr=pd.read_csv(fname_mkr,delimiter='\t',header=0,engine='c')
    x=mkr['COG_X']
    y=grf['COPNET_X']
    t=mkr['Time']
    x0=np.array(x[:-30]).reshape(-1,1)
    y0=np.array(y[30:]).reshape(-1,1)
    print(x0)
    #for nt in range(1,30):
      #  x0=np.hstack((x0,np.array(x[nt:-30+nt]).reshape(-1,1)))
    #c,d,_,_=np.linalg.lstsq(x0,y0,rcond=None)
# Out:
# [[0.23388 ]
#  [0.233829]
#  [0.23378 ]
#  ...
#  [0.221145]
#  [0.22116 ]
#  [0.221175]]
# [[0.26468 ]
#  [0.264616]
#  [0.264553]
#  ...
#  [0.253811]
#  [0.253855]
#  [0.2539  ]]
# [[0.23112 ]
#  [0.231138]
#  [0.231156]
#  ...
#  [0.21217 ]
#  [0.212147]
#  [0.212123]]
# [[0.22957 ]
#  [0.229555]
#  [0.229539]
#  ...
#  [0.216034]
#  [0.216008]
#  [0.215982]]
# [[0.23832 ]
#  [0.238323]
#  [0.238323]
#  ...
#  [0.2195  ]
#  [0.219522]
#  [0.219544]]
# [[0.23731 ]
#  [0.237203]
#  [0.237096]
#  ...
#  [0.222017]
#  [0.222049]
#  [0.222078]]
# [[0.20271 ]
#  [0.202759]
#  [0.202809]
#  ...
#  [0.210998]
#  [0.210969]
#  [0.210943]]
# [[0.22149 ]
#  [0.22149 ]
#  [0.221489]
#  ...
#  [0.211215]
#  [0.211242]
#  [0.211269]]
# [[0.23178 ]
#  [0.231815]
#  [0.23185 ]
#  ...
#  [0.231188]
#  [0.231202]
#  [0.231215]]
# [[0.25181 ]
#  [0.251791]
#  [0.251771]
#  ...
#  [0.258342]
#  [0.258307]
#  [0.258272]]
# [[0.23191 ]
#  [0.2319  ]
#  [0.23189 ]
#  ...
#  [0.229275]
#  [0.229267]
#  [0.229256]]
# [[0.21871 ]
#  [0.218715]
#  [0.218721]
#  ...
#  [0.208247]
#  [0.208208]
#  [0.208169]]
# [[0.21992 ]
#  [0.219894]
#  [0.219867]
#  ...
#  [0.231183]
#  [0.23118 ]
#  [0.231177]]
# [[0.21687 ]
#  [0.216872]
#  [0.216874]
#  ...
#  [0.217749]
#  [0.217745]
#  [0.217742]]
# [[0.203651]
#  [0.203766]
#  [0.203882]
#  ...
#  [0.20055 ]
#  [0.200568]
#  [0.200584]]
# [[0.26311 ]
#  [0.263116]
#  [0.263121]
#  ...
#  [0.25087 ]
#  [0.250861]
#  [0.250851]]
# [[0.21269 ]
#  [0.212717]
#  [0.212745]
#  ...
#  [0.202773]
#  [0.202765]
#  [0.202758]]
# [[0.20512 ]
#  [0.205113]
#  [0.205107]
#  ...
#  [0.202745]
#  [0.202788]
#  [0.202828]]
# [[0.24161 ]
#  [0.241575]
#  [0.241541]
#  ...
#  [0.228221]
#  [0.228314]
#  [0.22841 ]]
# [[0.25677 ]
#  [0.256779]
#  [0.256787]
#  ...
#  [0.261445]
#  [0.261459]
#  [0.261472]]
# [[0.19597 ]
#  [0.195945]
#  [0.195922]
#  ...
#  [0.200244]
#  [0.200254]
#  [0.200263]]
# [[0.22798 ]
#  [0.227976]
#  [0.227972]
#  ...
#  [0.220468]
#  [0.220443]
#  [0.220418]]
# [[0.2227  ]
#  [0.222679]
#  [0.222658]
#  ...
#  [0.221102]
#  [0.221083]
#  [0.221064]]
# [[0.21488 ]
#  [0.214854]
#  [0.21483 ]
#  ...
#  [0.216639]
#  [0.216595]
#  [0.216552]]
# [[0.25446 ]
#  [0.254442]
#  [0.254423]
#  ...
#  [0.252169]
#  [0.252177]
#  [0.252184]]
# [[0.24868 ]
#  [0.248651]
#  [0.248623]
#  ...
#  [0.23656 ]
#  [0.236564]
#  [0.236569]]
# [[0.24407 ]
#  [0.244013]
#  [0.243955]
#  ...
#  [0.243888]
#  [0.243895]
#  [0.243903]]
# [[0.2218  ]
#  [0.221769]
#  [0.221742]
#  ...
#  [0.21404 ]
#  [0.213977]
#  [0.213913]]
# [[0.22865 ]
#  [0.228565]
#  [0.228481]
#  ...
#  [0.209366]
#  [0.209403]
#  [0.20944 ]]
# [[0.21396 ]
#  [0.214031]
#  [0.214105]
#  ...
#  [0.213317]
#  [0.2133  ]
#  [0.213283]]
# [[0.21545 ]
#  [0.215489]
#  [0.215526]
#  ...
#  [0.202678]
#  [0.202784]
#  [0.202892]]
# [[0.21933 ]
#  [0.219264]
#  [0.219198]
#  ...
#  [0.224347]
#  [0.22437 ]
#  [0.224391]]
# [[nan]
#  [nan]
#  [nan]
#  ...
#  [nan]
#  [nan]
#  [nan]]
# [[0.2259  ]
#  [0.225935]
#  [0.22597 ]
#  ...
#  [0.225221]
#  [0.225215]
#  [0.225208]]
# [[0.24616 ]
#  [0.246147]
#  [0.246133]
#  ...
#  [0.243037]
#  [0.243004]
#  [0.242979]]
# [[0.2273  ]
#  [0.227236]
#  [0.227174]
#  ...
#  [0.226306]
#  [0.226318]
#  [0.22633 ]]
# [[0.22167 ]
#  [0.221723]
#  [0.221775]
#  ...
#  [0.210678]
#  [0.21065 ]
#  [0.210627]]
# [[0.2514  ]
#  [0.251394]
#  [0.251389]
#  ...
#  [0.2426  ]
#  [0.242607]
#  [0.24262 ]]
# [[0.24458 ]
#  [0.244612]
#  [0.244642]
#  ...
#  [0.258742]
#  [0.258778]
#  [0.258812]]
# [[0.21388 ]
#  [0.213909]
#  [0.213938]
#  ...
#  [0.215284]
#  [0.21527 ]
#  [0.215255]]
# [[0.22259 ]
#  [0.222538]
#  [0.222487]
#  ...
#  [0.230773]
#  [0.230773]
#  [0.230773]]
# [[0.22587 ]
#  [0.225843]
#  [0.225817]
#  ...
#  [0.227369]
#  [0.22736 ]
#  [0.227349]]
# [[0.20635 ]
#  [0.206343]
#  [0.206336]
#  ...
#  [0.207793]
#  [0.207807]
#  [0.20782 ]]
# [[0.22059 ]
#  [0.220564]
#  [0.220537]
#  ...
#  [0.226783]
#  [0.226794]
#  [0.226804]]
# [[0.23225 ]
#  [0.232282]
#  [0.232314]
#  ...
#  [0.248054]
#  [0.248066]
#  [0.248078]]
# [[0.20856 ]
#  [0.208585]
#  [0.208612]
#  ...
#  [0.209072]
#  [0.209041]
#  [0.209011]]
# [[0.22495 ]
#  [0.22493 ]
#  [0.22491 ]
#  ...
#  [0.223554]
#  [0.22352 ]
#  [0.223486]]
# [[0.22062 ]
#  [0.220625]
#  [0.220631]
#  ...
#  [0.209621]
#  [0.209593]
#  [0.209566]]
# [[0.25785 ]
#  [0.257764]
#  [0.25768 ]
#  ...
#  [0.251342]
#  [0.251332]
#  [0.251321]]

# %%
a=PDSinfo[PDSinfo['Subject']==49].index.tolist()[0:2]
print(a[0:2])
# Out:
# [576, 577]

# %% [markdown]
# Devemos calcular os coeficientes da equação que relaciona o COG com o COP

# %%
y=grf['COPNET_X']
x=mkr['COG_X']
t=mkr['Time']

# %% [markdown]
# First it is created the array with values of cop and cog, and then calculated their coefficients, in this case for Trial 150, subject 13.

# %%
x1=np.array(x[:-30]).reshape(-1,1)
y1=np.array(y[30:]).reshape(-1,1)
for nt in range(1,30):
    x1=np.hstack((x1,np.array(x[nt:-30+nt]).reshape(-1,1)))
N=len(x1)
f1=np.hstack((x1,np.ones((N,1))))
c,d,_,_=np.linalg.lstsq(x1,y1,rcond=None)

# %% [markdown]
# After the coefficients are calculated it is necessary to test the veracity of these values with other trials, for example 154

# %%
fname_grftest1=os.path.join(path2, PDSinfo.Trial[154]+'grf'+'.txt')
fname_mkrtest1=os.path.join(path2, PDSinfo.Trial[154]+'mkr'+'.txt')
grftest1=pd.read_csv(fname_grftest1, delimiter='\t', header=0, engine='c')
mkrtest1=pd.read_csv(fname_mkrtest1, delimiter='\t', header=0, engine='c')

# %%
u1=mkrtest1['COG_X']
v1=grftest1['COPNET_X']

# %% [markdown]
# Now it is done de arrays that gather the data from nt to nt-30 for trial 154

# %%
x1test1=np.array(u1[:-30]).reshape(-1,1)
y1test1=np.array(v1[30:]).reshape(-1,1)
for nt in range(1,30):
    x1test1=np.hstack((x1test1,np.array(u1[nt:-30+nt]).reshape(-1,1)))

# %% [markdown]
# It is time to plot the graphics with values of trial number 154 but using trial's 150 coeficient

# %%
yexttest1=x1test1@c
plt.plot(t[:-30],yexttest1,marker='', color='purple',linestyle='-')
plt.plot(t[:-30],v1[30:],marker='',color='red',linestyle='-')
plt.xlabel('Tempo')
plt.ylabel('COP')
# Out:
# Text(0, 0.5, 'COP')

# %% [markdown]
# Now it is calculated the mean square error:

# %%
yext1med=np.mean(yexttest1)
yreal1med=np.mean(v1[30:])
e1=np.sqrt(np.mean((yext1med-yreal1med)**2))
print(e1)
# Out:
# 0.0004716409771949315
