# %% [markdown]
# ## COP and COG estimation by derivative method
# Trying to estimate COP and COG were used linear function wich didn't give the results expected, therefore we tried to make different approaches and one of them is the next function:
# COP= COG-(4/g*3*d²derivadasegundaTeta)

# %% [markdown]
# ## Python libraries
#
# First, let's import the necessary Python libraries and configure the environment:

# %%
import numpy as np
#from scipy.signal import butter, filtfilt
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline
#import seaborn as sns
#sns.set_context("notebook", font_scale=1.3,
#                rc={'lines.linewidth': 1.5, 'lines.markersize': 14, 'axes.titlesize': 'x-large'})
#matplotlib.rc('legend', numpoints=1, fontsize=14)
#import glob
import sys, os
sys.path.insert(1, r'./Functions')
# IPython widgets:
from IPython.display import display
import ipywidgets
from ipywidgets import FloatProgress, interactive

# %% [markdown]
# Versions of the Python libraries used:

# %%
#!pip install version_information
# %load_ext version_information
# %version_information numpy, scipy, pandas, matplotlib, seaborn
# Out:
# Software versions
# Python 3.8.8 64bit [MSC v.1916 64 bit (AMD64)]
# IPython 7.22.0
# OS Windows 10 10.0.22000 SP0
# numpy 1.20.1
# scipy 1.6.2
# pandas 1.2.4
# matplotlib 3.3.4
# seaborn 0.11.1
# Wed Apr 06 23:36:34 2022 Hora oficial do Brasil

# %% [markdown]
# ## Meta data
#
# The file `PDSinfo.txt` contains meta data about the subjects and the experimental trials. The file has a header plus 588 rows per 29 columns (there are 12 rows for each of the 49 subjects).
# Let's use the power of the [pandas](http://pandas.pydata.org/) library to load and explore the meta data:

# %%
# GitHub URL:
#path2 = 'C:\Users\ferna\Downloads\IC- dados\Dados'
# local directory:
path2 = r'C:\\Users\\ferna\\Downloads\\IC- dados\\Dados'
fname = os.path.join(path2, 'PDSinfo.txt')
PDSinfo = pd.read_csv(fname, sep='\t', header=0, index_col=None, engine='c', encoding='utf-8')
print(fname)
print("Information of %s subjects loaded (%s rows, %s columns)."
      %(len(pd.unique(PDSinfo.Subject)), PDSinfo.shape[0], PDSinfo.shape[1]))
# Out:
# C:\\Users\\ferna\\Downloads\\IC- dados\\Dados\PDSinfo.txt
# Information of 49 subjects loaded (588 rows, 29 columns).

# %%
a=PDSinfo[PDSinfo['Subject']==44].index.tolist()
e=PDSinfo[PDSinfo['Subject']==44].index.tolist()[2]
print(a)
print(e)
# Out:
# [516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527]
# 518

# %% [markdown]
# Here are the first 12 rows and first 10 columns of meta data:

# %% [markdown]
# ## COP and COG displacements

# %% [markdown]
# ## For Every Subject

# %% [markdown]
# ## Corrrelation

# %%
import pandas as pd 
import seaborn as sns
for s in range (1,50):
    a=PDSinfo[PDSinfo['Subject']==s].index.tolist()[2]
    fname_grf = os.path.join(path2, PDSinfo.Trial[a] + 'grf' + '.txt') 
    fname_mkr = os.path.join(path2, PDSinfo.Trial[a] + 'mkr' + '.txt')
    grf = pd.read_csv(fname_grf, delimiter='\t', header=0, engine='c')
    mkr = pd.read_csv(fname_mkr, delimiter='\t', header=0, engine='c')
    COGX=mkr['COG_X']
    COGY=mkr['COG_Y']
    COGZ=mkr['COG_Z']
    d=(COGX**2+COGY**2+COGZ**2)**0.5
    angulox = np.arcsin(COGX/d)
    anguloz= np.arcsin(COGZ/d)
    matrizangx=np.array(angulox[30:])
    matrizangz=np.array(anguloz[30:])
    t=grf['Time']
    dt=t[1]-t[0]
    d1x=np.zeros(len(matrizangx))
    d1z=np.zeros(len(matrizangz))
    for i in range(0, len(matrizangx)-1):
        next=i+1
        d1x[i]=(matrizangx[next]-matrizangx[i])/dt
        d1z[i]=(matrizangz[next]-matrizangz[i])/dt
    d2x=np.zeros(len(d1x))
    d2z=np.zeros(len(d1z))
    for i in range(0, 30):
        next=i+1
        d2x[i]=(d1x[next]-d1x[i])/dt
        d2z[i]=(d1z[next]-d1z[i])/dt
    COPX=COGX[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2x
    COPZ=COGZ[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2z
    COPXreal=grf['COPNET_X']
    COPZreal=grf['COPNET_Z']
    COPZmatrix=np.array(COPZ)
    COPZrealmatrix=np.array(COPZreal[30:])
    errorz=np.subtract(COPZmatrix,COPZrealmatrix)

# %% [markdown]
# # Correlation between errorx and Second Derivative x

# %%
import pandas as pd 
import seaborn as sns
for s in range (1,50):
    a=PDSinfo[PDSinfo['Subject']==s].index.tolist()[2]
    fname_grf = os.path.join(path2, PDSinfo.Trial[a] + 'grf' + '.txt') 
    fname_mkr = os.path.join(path2, PDSinfo.Trial[a] + 'mkr' + '.txt')
    grf = pd.read_csv(fname_grf, delimiter='\t', header=0, engine='c')
    mkr = pd.read_csv(fname_mkr, delimiter='\t', header=0, engine='c')
    COGX=mkr['COG_X']
    COGY=mkr['COG_Y']
    COGZ=mkr['COG_Z']
    d=(COGX**2+COGY**2+COGZ**2)**0.5
    angulox = np.arcsin(COGX/d)
    anguloz= np.arcsin(COGZ/d)
    matrizangx=np.array(angulox[30:])
    matrizangz=np.array(anguloz[30:])
    t=grf['Time']
    dt=t[1]-t[0]
    d1x=np.zeros(len(matrizangx))
    d1z=np.zeros(len(matrizangz))
    for i in range(0, len(matrizangx)-1):
        next=i+1
        d1x[i]=(matrizangx[next]-matrizangx[i])/dt
        d1z[i]=(matrizangz[next]-matrizangz[i])/dt
    d2x=np.zeros(len(d1x))
    d2z=np.zeros(len(d1z))
    for i in range(0, 30):
        next=i+1
        d2x[i]=(d1x[next]-d1x[i])/dt
        d2z[i]=(d1z[next]-d1z[i])/dt
    COPX=COGX[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2x
    COPZ=COGZ[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2z
    COPXreal=grf['COPNET_X']
    COPZreal=grf['COPNET_Z']
    COPXmatrix=np.array(COPX)
    COPXrealmatrix=np.array(COPXreal[30:])
    COPZmatrix=np.array(COPZ)
    COPZrealmatrix=np.array(COPZreal[30:])
    errorx=np.subtract(COPXmatrix,COPXrealmatrix)
    errorz=np.subtract(COPZmatrix,COPZrealmatrix)
    data={'x':d2x,
         'y': errorx
         }
    df=pd.DataFrame(data)
    plt.figure()
    plt.plot('x','y','bo',data= df, marker='.')
    plt.xlabel("Second Derivative x")
    plt.ylabel("Errorx")
    plt.title("Correlation between errorx and Second Derivative x of Subject {}".format(s))
    plt.show()
    r=np.corrcoef(d2x,COPXmatrix)
    print(r)
    plt.figure()
    data={'x':d2x,
          'y': errorx
         }
    df=pd.DataFrame(data)
    plt.figure()
    correlation=df.corr()
    print(correlation)
    plot=sns.heatmap(correlation,annot= True, fmt='.1f',linewidths=.6)
    plt.show()
    plt.figure()
    correlationpearson=df.corr(method='pearson')
    print(correlationpearson)
    plot=sns.heatmap(correlationpearson,annot= True, fmt='.1f',linewidths=.6)
    plt.show()
    plt.figure()
    correlationspearman=df.corr(method='spearman')
    print(correlationspearman)
    plot=sns.heatmap(correlationspearman,annot= True, fmt='.1f',linewidths=.6)
    plt.show()
    #histogramas
    plt.figure()
    hist=plt.hist(errorx,color='purple',label="Errorx")
    hist2=plt.hist(d2x, color='blue',label="Second Derivative")
    plt.legend()
    plt.show()
# Out:
# [[ 1.         -0.09580624]
#  [-0.09580624  1.        ]]
#           x         y
# x  1.000000 -0.267268
# y -0.267268  1.000000
#           x         y
# x  1.000000 -0.100389
# y -0.100389  1.000000
# [[ 1.         -0.22668354]
#  [-0.22668354  1.        ]]
#           x         y
# x  1.000000 -0.145178
# y -0.145178  1.000000
#           x         y
# x  1.000000 -0.018738
# y -0.018738  1.000000
# [[ 1.         -0.16194931]
#  [-0.16194931  1.        ]]
#           x         y
# x  1.000000 -0.081171
# y -0.081171  1.000000
#           x         y
# x  1.000000 -0.054625
# y -0.054625  1.000000
# [[ 1.         -0.02182057]
#  [-0.02182057  1.        ]]
#          x        y
# x  1.00000 -0.13939
# y -0.13939  1.00000
#           x         y
# x  1.000000 -0.076132
# y -0.076132  1.000000
# [[ 1.        -0.0473313]
#  [-0.0473313  1.       ]]
#           x         y
# x  1.000000 -0.344401
# y -0.344401  1.000000
#           x         y
# x  1.000000 -0.077002
# y -0.077002  1.000000
# [[ 1.         -0.00951637]
#  [-0.00951637  1.        ]]
#           x         y
# x  1.000000 -0.104667
# y -0.104667  1.000000
#           x         y
# x  1.000000 -0.049081
# y -0.049081  1.000000
# [[ 1.         -0.00587161]
#  [-0.00587161  1.        ]]
#          x        y
# x  1.00000 -0.10113
# y -0.10113  1.00000
#           x         y
# x  1.000000 -0.059706
# y -0.059706  1.000000
# [[ 1.         -0.03255949]
#  [-0.03255949  1.        ]]
#           x         y
# x  1.000000 -0.205503
# y -0.205503  1.000000
#           x         y
# x  1.000000 -0.060546
# y -0.060546  1.000000
# [[1.         0.00657613]
#  [0.00657613 1.        ]]
#           x         y
# x  1.000000 -0.114311
# y -0.114311  1.000000
#           x         y
# x  1.000000 -0.054715
# y -0.054715  1.000000
# [[ 1.         -0.03617527]
#  [-0.03617527  1.        ]]
#           x         y
# x  1.000000 -0.120592
# y -0.120592  1.000000
#          x        y
# x  1.00000 -0.08956
# y -0.08956  1.00000
# [[ 1.         -0.20329582]
#  [-0.20329582  1.        ]]
#           x         y
# x  1.000000 -0.395397
# y -0.395397  1.000000
#           x         y
# x  1.000000 -0.078536
# y -0.078536  1.000000
# [[ 1.         -0.00771344]
#  [-0.00771344  1.        ]]
#           x         y
# x  1.000000 -0.091051
# y -0.091051  1.000000
#           x         y
# x  1.000000 -0.036604
# y -0.036604  1.000000
# [[ 1.         -0.04125995]
#  [-0.04125995  1.        ]]
#           x         y
# x  1.000000 -0.183188
# y -0.183188  1.000000
#           x         y
# x  1.000000 -0.066599
# y -0.066599  1.000000
# [[ 1.         -0.06172253]
#  [-0.06172253  1.        ]]
#           x         y
# x  1.000000 -0.065234
# y -0.065234  1.000000
#           x         y
# x  1.000000 -0.041538
# y -0.041538  1.000000
# [[ 1.         -0.04928773]
#  [-0.04928773  1.        ]]
#           x         y
# x  1.000000 -0.061892
# y -0.061892  1.000000
#           x         y
# x  1.000000  0.002664
# y  0.002664  1.000000
# [[ 1.         -0.01525455]
#  [-0.01525455  1.        ]]
#           x         y
# x  1.000000 -0.103429
# y -0.103429  1.000000
#           x         y
# x  1.000000 -0.067442
# y -0.067442  1.000000
# [[ 1.        -0.0339473]
#  [-0.0339473  1.       ]]
#           x         y
# x  1.000000 -0.088326
# y -0.088326  1.000000
#           x         y
# x  1.000000 -0.061883
# y -0.061883  1.000000
# [[ 1.         -0.02406467]
#  [-0.02406467  1.        ]]
#           x         y
# x  1.000000 -0.065071
# y -0.065071  1.000000
#           x         y
# x  1.000000 -0.022069
# y -0.022069  1.000000
# [[ 1.         -0.00915888]
#  [-0.00915888  1.        ]]
#           x         y
# x  1.000000 -0.132943
# y -0.132943  1.000000
#           x         y
# x  1.000000 -0.057108
# y -0.057108  1.000000
# [[ 1.         -0.04466914]
#  [-0.04466914  1.        ]]
#           x         y
# x  1.000000 -0.205744
# y -0.205744  1.000000
#           x         y
# x  1.000000 -0.098819
# y -0.098819  1.000000
# [[ 1.         -0.13111697]
#  [-0.13111697  1.        ]]
#           x         y
# x  1.000000 -0.325742
# y -0.325742  1.000000
#           x         y
# x  1.000000 -0.091416
# y -0.091416  1.000000
# [[ 1.         -0.16658107]
#  [-0.16658107  1.        ]]
#           x         y
# x  1.000000 -0.105284
# y -0.105284  1.000000
#           x         y
# x  1.000000 -0.081456
# y -0.081456  1.000000
# [[ 1.         -0.08680855]
#  [-0.08680855  1.        ]]
#           x         y
# x  1.000000 -0.174542
# y -0.174542  1.000000
#           x         y
# x  1.000000 -0.086788
# y -0.086788  1.000000
# [[ 1.         -0.05352237]
#  [-0.05352237  1.        ]]
#           x         y
# x  1.000000 -0.047961
# y -0.047961  1.000000
#           x         y
# x  1.000000 -0.011241
# y -0.011241  1.000000
# [[ 1.         -0.07317815]
#  [-0.07317815  1.        ]]
#           x         y
# x  1.000000 -0.132875
# y -0.132875  1.000000
#           x         y
# x  1.000000 -0.084195
# y -0.084195  1.000000
# [[ 1.         -0.08608609]
#  [-0.08608609  1.        ]]
#           x         y
# x  1.000000 -0.156601
# y -0.156601  1.000000
#           x         y
# x  1.000000 -0.056343
# y -0.056343  1.000000
# [[ 1.         -0.26231142]
#  [-0.26231142  1.        ]]
#           x         y
# x  1.000000 -0.154788
# y -0.154788  1.000000
#           x         y
# x  1.000000 -0.064942
# y -0.064942  1.000000
# [[ 1.         -0.00749063]
#  [-0.00749063  1.        ]]
#           x         y
# x  1.000000 -0.132724
# y -0.132724  1.000000
#           x         y
# x  1.000000 -0.074887
# y -0.074887  1.000000
# [[ 1.         -0.05291048]
#  [-0.05291048  1.        ]]
#           x         y
# x  1.000000 -0.029992
# y -0.029992  1.000000
#          x        y
# x  1.00000 -0.04078
# y -0.04078  1.00000
# [[1.         0.00813167]
#  [0.00813167 1.        ]]
#           x         y
# x  1.000000 -0.051823
# y -0.051823  1.000000
#           x         y
# x  1.000000 -0.057798
# y -0.057798  1.000000
# [[ 1.         -0.05001402]
#  [-0.05001402  1.        ]]
#           x         y
# x  1.000000 -0.070608
# y -0.070608  1.000000
#           x         y
# x  1.000000 -0.048471
# y -0.048471  1.000000
# [[ 1.         -0.01846818]
#  [-0.01846818  1.        ]]
#           x         y
# x  1.000000 -0.084006
# y -0.084006  1.000000
#           x         y
# x  1.000000 -0.048937
# y -0.048937  1.000000
# [[ 1.         -0.05498683]
#  [-0.05498683  1.        ]]
#           x         y
# x  1.000000 -0.068176
# y -0.068176  1.000000
#           x         y
# x  1.000000 -0.024844
# y -0.024844  1.000000
# [[ 1.         -0.09733751]
#  [-0.09733751  1.        ]]
#           x         y
# x  1.000000 -0.319981
# y -0.319981  1.000000
#           x         y
# x  1.000000 -0.009887
# y -0.009887  1.000000
# [[ 1.        -0.0658282]
#  [-0.0658282  1.       ]]
#           x         y
# x  1.000000 -0.041132
# y -0.041132  1.000000
#           x         y
# x  1.000000 -0.029102
# y -0.029102  1.000000
# [[ 1.        -0.1143715]
#  [-0.1143715  1.       ]]
#           x         y
# x  1.000000 -0.308027
# y -0.308027  1.000000
#           x         y
# x  1.000000 -0.110073
# y -0.110073  1.000000
# [[ 1.         -0.15653006]
#  [-0.15653006  1.        ]]
#          x        y
# x  1.00000 -0.04306
# y -0.04306  1.00000
#           x         y
# x  1.000000 -0.017442
# y -0.017442  1.000000
# [[ 1.         -0.09053709]
#  [-0.09053709  1.        ]]
#           x         y
# x  1.000000 -0.098738
# y -0.098738  1.000000
#           x         y
# x  1.000000 -0.089089
# y -0.089089  1.000000
# [[ 1.        -0.0220099]
#  [-0.0220099  1.       ]]
#           x         y
# x  1.000000 -0.012698
# y -0.012698  1.000000
#           x         y
# x  1.000000  0.007677
# y  0.007677  1.000000
# [[ 1.         -0.01503134]
#  [-0.01503134  1.        ]]
#           x         y
# x  1.000000 -0.168826
# y -0.168826  1.000000
#           x         y
# x  1.000000 -0.093779
# y -0.093779  1.000000
# [[1.       0.038192]
#  [0.038192 1.      ]]
#           x         y
# x  1.000000 -0.018268
# y -0.018268  1.000000
#           x         y
# x  1.000000  0.038541
# y  0.038541  1.000000
# [[ 1.         -0.10611309]
#  [-0.10611309  1.        ]]
#          x        y
# x  1.00000 -0.16241
# y -0.16241  1.00000
#           x         y
# x  1.000000 -0.086955
# y -0.086955  1.000000
# [[ 1.         -0.01314487]
#  [-0.01314487  1.        ]]
#           x         y
# x  1.000000 -0.106696
# y -0.106696  1.000000
#           x         y
# x  1.000000 -0.080339
# y -0.080339  1.000000
# [[ 1.         -0.18975416]
#  [-0.18975416  1.        ]]
#           x         y
# x  1.000000 -0.048602
# y -0.048602  1.000000
#           x         y
# x  1.000000 -0.019908
# y -0.019908  1.000000
# [[ 1.        -0.0733902]
#  [-0.0733902  1.       ]]
#           x         y
# x  1.000000 -0.394135
# y -0.394135  1.000000
#           x         y
# x  1.000000 -0.097906
# y -0.097906  1.000000
# [[1.         0.01165908]
#  [0.01165908 1.        ]]
#           x         y
# x  1.000000 -0.107806
# y -0.107806  1.000000
#           x         y
# x  1.000000 -0.077858
# y -0.077858  1.000000
# [[ 1.         -0.08612229]
#  [-0.08612229  1.        ]]
#           x         y
# x  1.000000 -0.157892
# y -0.157892  1.000000
#           x         y
# x  1.000000 -0.076536
# y -0.076536  1.000000
# [[1.         0.01448718]
#  [0.01448718 1.        ]]
#           x         y
# x  1.000000 -0.050762
# y -0.050762  1.000000
#           x         y
# x  1.000000 -0.042471
# y -0.042471  1.000000
# [[ 1.         -0.16434833]
#  [-0.16434833  1.        ]]
#           x         y
# x  1.000000 -0.046504
# y -0.046504  1.000000
#         x       y
# x  1.0000 -0.0149
# y -0.0149  1.0000

# %%
import pandas as pd 
import seaborn as sns
for s in range (1,50):
    a=PDSinfo[PDSinfo['Subject']==s].index.tolist()[2]
    fname_grf = os.path.join(path2, PDSinfo.Trial[a] + 'grf' + '.txt') 
    fname_mkr = os.path.join(path2, PDSinfo.Trial[a] + 'mkr' + '.txt')
    grf = pd.read_csv(fname_grf, delimiter='\t', header=0, engine='c')
    mkr = pd.read_csv(fname_mkr, delimiter='\t', header=0, engine='c')
    COGX=mkr['COG_X']
    COGY=mkr['COG_Y']
    COGZ=mkr['COG_Z']
    d=(COGX**2+COGY**2+COGZ**2)**0.5
    angulox = np.arcsin(COGX/d)
    anguloz= np.arcsin(COGZ/d)
    matrizangx=np.array(angulox[30:])
    matrizangz=np.array(anguloz[30:])
    t=grf['Time']
    dt=t[1]-t[0]
    d1x=np.zeros(len(matrizangx))
    d1z=np.zeros(len(matrizangz))
    for i in range(0, len(matrizangx)-1):
        next=i+1
        d1x[i]=(matrizangx[next]-matrizangx[i])/dt
        d1z[i]=(matrizangz[next]-matrizangz[i])/dt
    d2x=np.zeros(len(d1x))
    d2z=np.zeros(len(d1z))
    for i in range(0, 30):
        next=i+1
        d2x[i]=(d1x[next]-d1x[i])/dt
        d2z[i]=(d1z[next]-d1z[i])/dt
    COPX=COGX[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2x
    COPZ=COGZ[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2z
    COPXreal=grf['COPNET_X']
    COPZreal=grf['COPNET_Z']
    COPXmatrix=np.array(COPX)
    COPXrealmatrix=np.array(COPXreal[30:])
    COPZmatrix=np.array(COPZ)
    COPZrealmatrix=np.array(COPZreal[30:])
    errorx=np.subtract(COPXmatrix,COPXrealmatrix)
    errorz=np.subtract(COPZmatrix,COPZrealmatrix)
    data={'x':d2x,
         'y': errorx
         }
    df=pd.DataFrame(data)
    mediaerro=(np.sum(errorx))/(len(errorx))
    mediad2x=(np.sum(d2x))/(len(d2x))
    print("A média de erros de {} é {}".format(s,mediaerro))
    print("A média da segunda derivada de {} é {}".format(s,mediad2x))
    varx=[]
    for i in range(0,len(d2x)):
        varx.append((d2x[i]-mediad2x)**2)
    varx2=(np.sum(varx))/(len(d2x))
    dpx=varx2**0.5
    vary=[]
    for u in range(0,len(errorx)):
        vary.append((errorx[u]-mediaerro)**2)
    vary2=(np.sum(vary))/(len(errorx))
    dpy=vary2**0.5
    print("O desvio padrão do erro de {} é {}".format(s,dpx))
    print("O desvio padrão da segunda derivada de {} é {}".format(s,dpy))
# Out:
# A média de erros de 1 é 0.005014038637798487
# A média da segunda derivada de 1 é 5.327050731024975e-05
# O desvio padrão do erro de 1 é 0.0017888101080713013
# O desvio padrão da segunda derivada de 1 é 0.000986995638487179
# A média de erros de 2 é 0.008925908542875671
# A média da segunda derivada de 2 é -0.00014358034326669743
# O desvio padrão do erro de 2 é 0.002258916791710221
# O desvio padrão da segunda derivada de 2 é 0.001209888610494493
# A média de erros de 3 é 0.014646969064340291
# A média da segunda derivada de 3 é -6.688054325076444e-05
# O desvio padrão do erro de 3 é 0.0013069383620302715
# O desvio padrão da segunda derivada de 3 é 0.0008034862453521203
# A média de erros de 4 é 0.00703377074901502
# A média da segunda derivada de 4 é -3.383720433477085e-07
# O desvio padrão do erro de 4 é 0.0008057235494756683
# O desvio padrão da segunda derivada de 4 é 0.0008715794789832675
# A média de erros de 5 é 0.002990522746092952
# A média da segunda derivada de 5 é 7.016056551200742e-06
# O desvio padrão do erro de 5 é 0.0015030599593688098
# O desvio padrão da segunda derivada de 5 é 0.0008056898354465203
# A média de erros de 6 é 0.021427999675802518
# A média da segunda derivada de 6 é 1.225031083813458e-05
# O desvio padrão do erro de 6 é 0.0009485286870635163
# O desvio padrão da segunda derivada de 6 é 0.0010683905753492325
# A média de erros de 7 é 0.007876791510859954
# A média da segunda derivada de 7 é 5.624703404927453e-06
# O desvio padrão do erro de 7 é 0.0011340763384706997
# O desvio padrão da segunda derivada de 7 é 0.0010372416703831491
# A média de erros de 8 é 0.002123513146972836
# A média da segunda derivada de 8 é 3.2089041251187454e-05
# O desvio padrão do erro de 8 é 0.0009963137158971675
# O desvio padrão da segunda derivada de 8 é 0.0007739180331167677
# A média de erros de 9 é 0.01709943205393563
# A média da segunda derivada de 9 é -1.9571028716954747e-05
# O desvio padrão do erro de 9 é 0.0008311926176508815
# O desvio padrão da segunda derivada de 9 é 0.0007662687760660002
# A média de erros de 10 é 0.016304141276305556
# A média da segunda derivada de 10 é -1.9994952472722514e-05
# O desvio padrão do erro de 10 é 0.0007911593371078956
# O desvio padrão da segunda derivada de 10 é 0.0008140373107058256
# A média de erros de 11 é 0.0009486758855669475
# A média da segunda derivada de 11 é -0.00020081552719801075
# O desvio padrão do erro de 11 é 0.003357440236211849
# O desvio padrão da segunda derivada de 11 é 0.0013025235844798834
# A média de erros de 12 é 0.013354713669381218
# A média da segunda derivada de 12 é 8.443933195593463e-06
# O desvio padrão do erro de 12 é 0.0009404062236953247
# O desvio padrão da segunda derivada de 12 é 0.0010439030935419083
# A média de erros de 13 é 0.005068922767120797
# A média da segunda derivada de 13 é 8.607765100419877e-05
# O desvio padrão do erro de 13 é 0.001846824904440069
# O desvio padrão da segunda derivada de 13 é 0.000996773540771686
# A média de erros de 14 é 0.008660172326849768
# A média da segunda derivada de 14 é -2.046434006572642e-05
# O desvio padrão do erro de 14 é 0.0011239313371960036
# O desvio padrão da segunda derivada de 14 é 0.0009882262218361792
# A média de erros de 15 é 0.001278710548302494
# A média da segunda derivada de 15 é -0.00015256730901082045
# O desvio padrão do erro de 15 é 0.0027943492435185215
# O desvio padrão da segunda derivada de 15 é 0.0010541187236084216
# A média de erros de 16 é 0.004998293428625886
# A média da segunda derivada de 16 é -4.0545185322865614e-07
# O desvio padrão do erro de 16 é 0.0005707227723897961
# O desvio padrão da segunda derivada de 16 é 0.0008553428913816742
# A média de erros de 17 é 0.0012158361466557451
# A média da segunda derivada de 17 é -4.394552122534709e-06
# O desvio padrão do erro de 17 é 0.0007231565400980344
# O desvio padrão da segunda derivada de 17 é 0.0011068405148907908
# A média de erros de 18 é 0.009175711560492874
# A média da segunda derivada de 18 é -1.4048646627183388e-06
# O desvio padrão do erro de 18 é 0.0010206848254335995
# O desvio padrão da segunda derivada de 18 é 0.0010449053488558219
# A média de erros de 19 é 0.012314658101606014
# A média da segunda derivada de 19 é 4.0477387046845676e-05
# O desvio padrão do erro de 19 é 0.0017953131163198847
# O desvio padrão da segunda derivada de 19 é 0.0009288298761345774
# A média de erros de 20 é 0.012746698502818048
# A média da segunda derivada de 20 é 9.080919234095175e-06
# O desvio padrão do erro de 20 é 0.0010318675323578313
# O desvio padrão da segunda derivada de 20 é 0.001038269531972773
# A média de erros de 21 é 0.010794572974635272
# A média da segunda derivada de 21 é -5.864722621285106e-05
# O desvio padrão do erro de 21 é 0.0034675765515139708
# O desvio padrão da segunda derivada de 21 é 0.0012416546337133375
# A média de erros de 22 é 0.007176822805755086
# A média da segunda derivada de 22 é -5.4956831158816265e-05
# O desvio padrão do erro de 22 é 0.0011900823810277337
# O desvio padrão da segunda derivada de 22 é 0.0012287352561505117
# A média de erros de 23 é 0.00975040642493742
# A média da segunda derivada de 23 é -1.896671349811331e-05
# O desvio padrão do erro de 23 é 0.0008586163070605938
# O desvio padrão da segunda derivada de 23 é 0.00067896863471168
# A média de erros de 24 é -0.0010766937008505537
# A média da segunda derivada de 24 é -0.00010756267312773539
# O desvio padrão do erro de 24 é 0.0018859446209770418
# O desvio padrão da segunda derivada de 24 é 0.0013670916149640276
# A média de erros de 25 é 0.016601466716874756
# A média da segunda derivada de 25 é -3.110451718478376e-05
# O desvio padrão do erro de 25 é 0.0011519913622699315
# O desvio padrão da segunda derivada de 25 é 0.0007726766438671894
# A média de erros de 26 é 0.0033994234392528988
# A média da segunda derivada de 26 é -1.7384836230932408e-05
# O desvio padrão do erro de 26 é 0.0011868804832899972
# O desvio padrão da segunda derivada de 26 é 0.0009890659623770775
# A média de erros de 27 é 0.010675488460389003
# A média da segunda derivada de 27 é -7.183551950688335e-05
# O desvio padrão do erro de 27 é 0.0013931716918596667
# O desvio padrão da segunda derivada de 27 é 0.0009110058246478696
# A média de erros de 28 é -0.007141596520542967
# A média da segunda derivada de 28 é 9.41483602048574e-05
# O desvio padrão do erro de 28 é 0.0016625167759232518
# O desvio padrão da segunda derivada de 28 é 0.001255900997717548
# A média de erros de 29 é -0.004493535856742755
# A média da segunda derivada de 29 é -2.0499887328514676e-05
# O desvio padrão do erro de 29 é 0.0006848207578167221
# O desvio padrão da segunda derivada de 29 é 0.0015048596351589798
# A média de erros de 30 é -0.007822730148832594
# A média da segunda derivada de 30 é 1.60739755060138e-05
# O desvio padrão do erro de 30 é 0.0011021175732769948
# O desvio padrão da segunda derivada de 30 é 0.0011456218001112395
# A média de erros de 31 é 0.007430522383919614
# A média da segunda derivada de 31 é 0.0001774623842524246
# O desvio padrão do erro de 31 é 0.003227399490460634
# O desvio padrão da segunda derivada de 31 é 0.0016009098058299338
# A média de erros de 32 é 0.008125281246104477
# A média da segunda derivada de 32 é 0.00012801716862855352
# O desvio padrão do erro de 32 é 0.0031306202302237495
# O desvio padrão da segunda derivada de 32 é 0.001555708359424855
# A média de erros de 33 é 0.008875566540271947
# A média da segunda derivada de 33 é -1.863665993379051e-05
# O desvio padrão do erro de 33 é 0.0009395721163018729
# O desvio padrão da segunda derivada de 33 é 0.0007304578884844099
# A média de erros de 34 é 0.01802898121174355
# A média da segunda derivada de 34 é -6.834765052283712e-05
# O desvio padrão do erro de 34 é 0.004196403438531444
# O desvio padrão da segunda derivada de 34 é 0.0011777268924005164
# A média de erros de 35 é 0.013649028135318729
# A média da segunda derivada de 35 é 7.71172824752468e-05
# O desvio padrão do erro de 35 é 0.0016432239374370688
# O desvio padrão da segunda derivada de 35 é 0.001562257372668255
# A média de erros de 36 é -0.005157504882208247
# A média da segunda derivada de 36 é -5.6688365456576944e-05
# O desvio padrão do erro de 36 é 0.003943265805530463
# O desvio padrão da segunda derivada de 36 é 0.0011742992309426534
# A média de erros de 37 é 0.009371727337475723
# A média da segunda derivada de 37 é -0.00015343719423534675
# O desvio padrão do erro de 37 é 0.0027395600962915605
# O desvio padrão da segunda derivada de 37 é 0.0014478937408488974
# A média de erros de 38 é -0.009177028667956597
# A média da segunda derivada de 38 é 5.9483043826277845e-05
# O desvio padrão do erro de 38 é 0.0010952516702467524
# O desvio padrão da segunda derivada de 38 é 0.0012846583184057717
# A média de erros de 39 é 0.019730312062656432
# A média da segunda derivada de 39 é -2.1826221262365547e-05
# O desvio padrão do erro de 39 é 0.0007199792720248774
# O desvio padrão da segunda derivada de 39 é 0.0013617325280645986
# A média de erros de 40 é 0.010689912139214408
# A média da segunda derivada de 40 é -2.5208705410015526e-05
# O desvio padrão do erro de 40 é 0.00149355896984394
# O desvio padrão da segunda derivada de 40 é 0.0007344953307019268
# A média de erros de 41 é 0.004316271395715934
# A média da segunda derivada de 41 é -3.3338507022774885e-05
# O desvio padrão do erro de 41 é 0.0013553177428928167
# O desvio padrão da segunda derivada de 41 é 0.0012948868060283396
# A média de erros de 42 é 0.018767603459217845
# A média da segunda derivada de 42 é -2.9860183299550873e-05
# O desvio padrão do erro de 42 é 0.0009286108758617476
# O desvio padrão da segunda derivada de 42 é 0.00045795061329799626
# A média de erros de 43 é 0.0010018805164942962
# A média da segunda derivada de 43 é 2.2499831010562188e-05
# O desvio padrão do erro de 43 é 0.0009361750181594406
# O desvio padrão da segunda derivada de 43 é 0.0010458658367625037
# A média de erros de 44 é -0.012815059619256391
# A média da segunda derivada de 44 é 8.82194495214018e-05
# O desvio padrão do erro de 44 é 0.00149919108061274
# O desvio padrão da segunda derivada de 44 é 0.0012698570999218766
# A média de erros de 45 é 0.014826933708696232
# A média da segunda derivada de 45 é 0.00017520315139370375
# O desvio padrão do erro de 45 é 0.005821529041769746
# O desvio padrão da segunda derivada de 45 é 0.0017474169006011175
# A média de erros de 46 é 0.011436419606523111
# A média da segunda derivada de 46 é 2.3123395685750413e-05
# O desvio padrão do erro de 46 é 0.0011010902504865394
# O desvio padrão da segunda derivada de 46 é 0.001443069201256341
# A média de erros de 47 é 0.005724576918842246
# A média da segunda derivada de 47 é -2.4737501368661242e-05
# O desvio padrão do erro de 47 é 0.0014812004301320589
# O desvio padrão da segunda derivada de 47 é 0.0007273041050010181
# A média de erros de 48 é 0.006508893931459767
# A média da segunda derivada de 48 é 9.303710898841618e-05
# O desvio padrão do erro de 48 é 0.0018752567772005082
# O desvio padrão da segunda derivada de 48 é 0.0013959865446523793
# A média de erros de 49 é 0.016302433120380405
# A média da segunda derivada de 49 é -3.609708218541496e-05
# O desvio padrão do erro de 49 é 0.0011300994928038423
# O desvio padrão da segunda derivada de 49 é 0.00130883885026479

# %% [markdown]
# Correlation between errorz and Second Derivative z

# %%
import pandas as pd 
import seaborn as sns
for s in range (1,50):
    a=PDSinfo[PDSinfo['Subject']==s].index.tolist()[2]
    fname_grf = os.path.join(path2, PDSinfo.Trial[a] + 'grf' + '.txt') 
    fname_mkr = os.path.join(path2, PDSinfo.Trial[a] + 'mkr' + '.txt')
    grf = pd.read_csv(fname_grf, delimiter='\t', header=0, engine='c')
    mkr = pd.read_csv(fname_mkr, delimiter='\t', header=0, engine='c')
    COGX=mkr['COG_X']
    COGY=mkr['COG_Y']
    COGZ=mkr['COG_Z']
    d=(COGX**2+COGY**2+COGZ**2)**0.5
    angulox = np.arcsin(COGX/d)
    anguloz= np.arcsin(COGZ/d)
    matrizangx=np.array(angulox[30:])
    matrizangz=np.array(anguloz[30:])
    t=grf['Time']
    dt=t[1]-t[0]
    d1x=np.zeros(len(matrizangx))
    d1z=np.zeros(len(matrizangz))
    for i in range(0, len(matrizangx)-1):
        next=i+1
        d1x[i]=(matrizangx[next]-matrizangx[i])/dt
        d1z[i]=(matrizangz[next]-matrizangz[i])/dt
    d2x=np.zeros(len(d1x))
    d2z=np.zeros(len(d1z))
    for i in range(0, 30):
        next=i+1
        d2x[i]=(d1x[next]-d1x[i])/dt
        d2z[i]=(d1z[next]-d1z[i])/dt
    COPX=COGX[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2x
    COPZ=COGZ[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2z
    COPXreal=grf['COPNET_X']
    COPZreal=grf['COPNET_Z']
    COPXmatrix=np.array(COPX)
    COPXrealmatrix=np.array(COPXreal[30:])
    COPZmatrix=np.array(COPZ)
    COPZrealmatrix=np.array(COPZreal[30:])
    errorx=np.subtract(COPXmatrix,COPXrealmatrix)
    errorz=np.subtract(COPZmatrix,COPZrealmatrix)
    data={'x':d2z,
         'y': errorz
         }
    df=pd.DataFrame(data)
    plt.plot('x','y','bo',data= df, marker='.')
    plt.xlabel("Second Derivative z")
    plt.ylabel("Errorz")
    plt.title("Correlation between errorz and Second Derivative z of Subject {}".format(s))
    plt.show()
    r=np.corrcoef(d2z,errorz)
    print(r)
    plt.figure()
    correlation=df.corr()
    plot=sns.heatmap(correlation,annot= True, fmt='.1f',linewidths=.6)
    plt.show()
    
    #histogramas
    plt.figure()
    hist=plt.hist(errorz,color='purple',label="Errorx")
    hist2=plt.hist(d2z, color='blue',label="Second Derivative")
    plt.legend()
    plt.show()
    mediaerro=(np.sum(errorz))/(len(errorz))
    mediad2x=(np.sum(d2z))/(len(d2z))
    print("A média de erros é {}".format(mediaerro))
# Out:
# [[ 1.         -0.11212859]
#  [-0.11212859  1.        ]]
# A média de erros é -0.006894928918740204
# [[ 1.         -0.15649492]
#  [-0.15649492  1.        ]]
# A média de erros é -0.00231390774670916
# [[ 1.         -0.10834905]
#  [-0.10834905  1.        ]]
# A média de erros é -0.0037118016774054336
# [[ 1.         -0.15589562]
#  [-0.15589562  1.        ]]
# A média de erros é -0.0014290043885836915
# [[ 1.         -0.32958939]
#  [-0.32958939  1.        ]]
# A média de erros é -0.005411882354216867
# [[ 1.         -0.14279793]
#  [-0.14279793  1.        ]]
# A média de erros é 0.0030608344371635524
# [[ 1.         -0.12301547]
#  [-0.12301547  1.        ]]
# A média de erros é 0.0007976929752023682
# [[ 1.         -0.29590303]
#  [-0.29590303  1.        ]]
# A média de erros é -0.00022540160999358897
# [[ 1.         -0.15306868]
#  [-0.15306868  1.        ]]
# A média de erros é -0.0012158977179692059
# [[ 1.         -0.20417772]
#  [-0.20417772  1.        ]]
# A média de erros é 0.002053376533879568
# [[ 1.         -0.23948448]
#  [-0.23948448  1.        ]]
# A média de erros é -0.0008888200872174474
# [[ 1.         -0.14018579]
#  [-0.14018579  1.        ]]
# A média de erros é -0.00018422924533928638
# [[ 1.         -0.21687613]
#  [-0.21687613  1.        ]]
# A média de erros é 0.0007839131479779164
# [[ 1.         -0.24524129]
#  [-0.24524129  1.        ]]
# A média de erros é -0.001558103992594667
# [[ 1.         -0.06381031]
#  [-0.06381031  1.        ]]
# A média de erros é -0.0004300884319425306
# [[ 1.         -0.19091792]
#  [-0.19091792  1.        ]]
# A média de erros é -0.0023209502381047417
# [[ 1.         -0.14564425]
#  [-0.14564425  1.        ]]
# A média de erros é 0.002468542588172599
# [[ 1.         -0.07683715]
#  [-0.07683715  1.        ]]
# A média de erros é -0.0010476543552583682
# [[ 1.         -0.38344286]
#  [-0.38344286  1.        ]]
# A média de erros é -0.0022515044493196393
# [[ 1.         -0.30352403]
#  [-0.30352403  1.        ]]
# A média de erros é 5.3619653436236505e-05
# [[ 1.         -0.07257444]
#  [-0.07257444  1.        ]]
# A média de erros é -0.0006974310150996449
# [[ 1.         -0.07711146]
#  [-0.07711146  1.        ]]
# A média de erros é 0.003483201352215529
# [[ 1.         -0.18965687]
#  [-0.18965687  1.        ]]
# A média de erros é -0.00031721374400483024
# [[ 1.         -0.05928375]
#  [-0.05928375  1.        ]]
# A média de erros é 0.0048079097350656975
# [[ 1.         -0.21172368]
#  [-0.21172368  1.        ]]
# A média de erros é 0.0022740972024253214
# [[ 1.         -0.24793899]
#  [-0.24793899  1.        ]]
# A média de erros é -0.0019603690377657692
# [[ 1.         -0.11963627]
#  [-0.11963627  1.        ]]
# A média de erros é -0.0017954820014506251
# [[ 1.         -0.09005772]
#  [-0.09005772  1.        ]]
# A média de erros é 0.001312252638526797
# [[ 1.         -0.08018004]
#  [-0.08018004  1.        ]]
# A média de erros é -0.00926509909127329
# [[ 1.         -0.09165696]
#  [-0.09165696  1.        ]]
# A média de erros é -0.002856002599926907
# [[ 1.         -0.06150264]
#  [-0.06150264  1.        ]]
# A média de erros é 0.0009090272467686463
# [[ 1.         -0.37590749]
#  [-0.37590749  1.        ]]
# A média de erros é -0.00017274897780544566
# [[ 1.         -0.16887052]
#  [-0.16887052  1.        ]]
# A média de erros é -0.0016725032532885545
# [[ 1.         -0.18632433]
#  [-0.18632433  1.        ]]
# A média de erros é -0.0011118612316888094
# [[ 1.         -0.06881592]
#  [-0.06881592  1.        ]]
# A média de erros é -0.0024117829126533543
# [[ 1.         -0.22780183]
#  [-0.22780183  1.        ]]
# A média de erros é -0.004801374563299606
# [[ 1.         -0.48540704]
#  [-0.48540704  1.        ]]
# A média de erros é -0.0019476696421333144
# [[ 1.         -0.10802227]
#  [-0.10802227  1.        ]]
# A média de erros é 0.0019774153558918105
# [[ 1.        -0.0828969]
#  [-0.0828969  1.       ]]
# A média de erros é -0.015259474496516504
# [[ 1.         -0.15654001]
#  [-0.15654001  1.        ]]
# A média de erros é -0.010631403422549094
# [[ 1.         -0.08878942]
#  [-0.08878942  1.        ]]
# A média de erros é 0.002458850169466991
# [[ 1.         -0.26614169]
#  [-0.26614169  1.        ]]
# A média de erros é 0.004091423382018273
# [[ 1.         -0.10000327]
#  [-0.10000327  1.        ]]
# A média de erros é 0.007649576754530139
# [[ 1.         -0.24901962]
#  [-0.24901962  1.        ]]
# A média de erros é -0.015163915778901211
# [[ 1.         -0.86745102]
#  [-0.86745102  1.        ]]
# A média de erros é -0.003850358757093523
# [[ 1.         -0.22142359]
#  [-0.22142359  1.        ]]
# A média de erros é 0.008474062243882025
# [[ 1.         -0.16762527]
#  [-0.16762527  1.        ]]
# A média de erros é -0.0014042386557129127
# [[ 1.         -0.10169965]
#  [-0.10169965  1.        ]]
# A média de erros é 0.00019817602157060817
# [[ 1.         -0.11238164]
#  [-0.11238164  1.        ]]
# A média de erros é -0.0020871621728811634

# %%
import pandas as pd 
import seaborn as sns
for s in range (1,50):
    a=PDSinfo[PDSinfo['Subject']==s].index.tolist()[2]
    fname_grf = os.path.join(path2, PDSinfo.Trial[a] + 'grf' + '.txt') 
    fname_mkr = os.path.join(path2, PDSinfo.Trial[a] + 'mkr' + '.txt')
    grf = pd.read_csv(fname_grf, delimiter='\t', header=0, engine='c')
    mkr = pd.read_csv(fname_mkr, delimiter='\t', header=0, engine='c')
    COGX=mkr['COG_X']
    COGY=mkr['COG_Y']
    COGZ=mkr['COG_Z']
    d=(COGX**2+COGY**2+COGZ**2)**0.5
    angulox = np.arcsin(COGX/d)
    anguloz= np.arcsin(COGZ/d)
    matrizangx=np.array(angulox[30:])
    matrizangz=np.array(anguloz[30:])
    t=grf['Time']
    dt=t[1]-t[0]
    d1x=np.zeros(len(matrizangx))
    d1z=np.zeros(len(matrizangz))
    for i in range(0, len(matrizangx)-1):
        next=i+1
        d1x[i]=(matrizangx[next]-matrizangx[i])/dt
        d1z[i]=(matrizangz[next]-matrizangz[i])/dt
    d2x=np.zeros(len(d1x))
    d2z=np.zeros(len(d1z))
    for i in range(0, 30):
        next=i+1
        d2x[i]=(d1x[next]-d1x[i])/dt
        d2z[i]=(d1z[next]-d1z[i])/dt
    COPX=COGX[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2x
    COPZ=COGZ[30:]-(4/3)*(d[30:]**4)*(1/9.8)*d2z
    COPXreal=grf['COPNET_X']
    COPZreal=grf['COPNET_Z']
    COPXmatrix=np.array(COPX)
    COPXrealmatrix=np.array(COPXreal[30:])
    COPZmatrix=np.array(COPZ)
    COPZrealmatrix=np.array(COPZreal[30:])
    errorx=np.subtract(COPXmatrix,COPXrealmatrix)
    errorz=np.subtract(COPZmatrix,COPZrealmatrix)
    mediaerro=(np.sum(errorz))/(len(errorz))
    mediad2z=(np.sum(d2z))/(len(d2z))
    print("A média de erros de {} é {}".format(s,mediaerro))
    print("A média da segunda derivada de {} é {}".format(s,mediad2z))
    varx=[]
    for i in range(0,len(d2z)):
        varx.append((d2z[i]-mediad2z)**2)
    varx2=(np.sum(varx))/(len(d2z))
    dpx=varx2**0.5
    vary=[]
    for u in range(0,len(errorz)):
        vary.append((errorz[u]-mediaerro)**2)
    vary2=(np.sum(vary))/(len(errorz))
    dpy=vary2**0.5
    print("O desvio padrão do erro de {} é {}".format(s,dpx))
    print("O desvio padrão da segunda derivada de {} é {}".format(s,dpy))
# Out:
# A média de erros de 1 é -0.006894928918740204
# A média da segunda derivada de 1 é -2.9970532488865606e-05
# O desvio padrão do erro de 1 é 0.0010632736476765305
# O desvio padrão da segunda derivada de 1 é 0.0008867865750134703
# A média de erros de 2 é -0.00231390774670916
# A média da segunda derivada de 2 é -3.982035168655389e-05
# O desvio padrão do erro de 2 é 0.000995749014988681
# O desvio padrão da segunda derivada de 2 é 0.0009795622423632664
# A média de erros de 3 é -0.0037118016774054336
# A média da segunda derivada de 3 é 1.0854597505352033e-08
# O desvio padrão do erro de 3 é 0.0007949456292620517
# O desvio padrão da segunda derivada de 3 é 0.0008782590509064642
# A média de erros de 4 é -0.0014290043885836915
# A média da segunda derivada de 4 é 8.024222634486008e-06
# O desvio padrão do erro de 4 é 0.0005959091902042738
# O desvio padrão da segunda derivada de 4 é 0.0005807178581134242
# A média de erros de 5 é -0.005411882354216867
# A média da segunda derivada de 5 é -6.10507530419818e-05
# O desvio padrão do erro de 5 é 0.0013454709063169023
# O desvio padrão da segunda derivada de 5 é 0.0007544345053425123
# A média de erros de 6 é 0.0030608344371635524
# A média da segunda derivada de 6 é 3.27276168612999e-05
# O desvio padrão do erro de 6 é 0.0009145526221056654
# O desvio padrão da segunda derivada de 6 é 0.0007766658389246859
# A média de erros de 7 é 0.0007976929752023682
# A média da segunda derivada de 7 é -6.823361586378057e-05
# O desvio padrão do erro de 7 é 0.0014318498200917742
# O desvio padrão da segunda derivada de 7 é 0.0006730893853375171
# A média de erros de 8 é -0.00022540160999358897
# A média da segunda derivada de 8 é 6.1571261267387804e-06
# O desvio padrão do erro de 8 é 0.0007448451882711337
# O desvio padrão da segunda derivada de 8 é 0.0004556599145827135
# A média de erros de 9 é -0.0012158977179692059
# A média da segunda derivada de 9 é 1.7085108286958573e-05
# O desvio padrão do erro de 9 é 0.0006980201813253334
# O desvio padrão da segunda derivada de 9 é 0.0004776899132381358
# A média de erros de 10 é 0.002053376533879568
# A média da segunda derivada de 10 é -6.267637079583973e-05
# O desvio padrão do erro de 10 é 0.0012310214404104751
# O desvio padrão da segunda derivada de 10 é 0.00045574108133280243
# A média de erros de 11 é -0.0008888200872174474
# A média da segunda derivada de 11 é 3.62180893646413e-05
# O desvio padrão do erro de 11 é 0.0010024969929689697
# O desvio padrão da segunda derivada de 11 é 0.0006651344116766022
# A média de erros de 12 é -0.00018422924533928638
# A média da segunda derivada de 12 é 2.0308013880015284e-05
# O desvio padrão do erro de 12 é 0.0011144408465107746
# O desvio padrão da segunda derivada de 12 é 0.0006073694240911743
# A média de erros de 13 é 0.0007839131479779164
# A média da segunda derivada de 13 é 3.788309900668997e-05
# O desvio padrão do erro de 13 é 0.0011830822348800243
# O desvio padrão da segunda derivada de 13 é 0.0007360111912890545
# A média de erros de 14 é -0.001558103992594667
# A média da segunda derivada de 14 é -1.5792957696259238e-05
# O desvio padrão do erro de 14 é 0.0010650696236710214
# O desvio padrão da segunda derivada de 14 é 0.0005204409061699695
# A média de erros de 15 é -0.0004300884319425306
# A média da segunda derivada de 15 é -5.468728889880281e-05
# O desvio padrão do erro de 15 é 0.0012217208024659027
# O desvio padrão da segunda derivada de 15 é 0.0006403602846302147
# A média de erros de 16 é -0.0023209502381047417
# A média da segunda derivada de 16 é 6.471103147687076e-06
# O desvio padrão do erro de 16 é 0.0009167102868202769
# O desvio padrão da segunda derivada de 16 é 0.0007759602052469357
# A média de erros de 17 é 0.002468542588172599
# A média da segunda derivada de 17 é -4.003164242370109e-05
# O desvio padrão do erro de 17 é 0.0009633733531197994
# O desvio padrão da segunda derivada de 17 é 0.0007232033877827308
# A média de erros de 18 é -0.0010476543552583682
# A média da segunda derivada de 18 é -3.674022726981931e-05
# O desvio padrão do erro de 18 é 0.0009657847686035774
# O desvio padrão da segunda derivada de 18 é 0.0007280541799852179
# A média de erros de 19 é -0.0022515044493196393
# A média da segunda derivada de 19 é -3.480060799441799e-05
# O desvio padrão do erro de 19 é 0.0022711972489738636
# O desvio padrão da segunda derivada de 19 é 0.0007985181797858815
# A média de erros de 20 é 5.3619653436236505e-05
# A média da segunda derivada de 20 é 4.367816377007688e-06
# O desvio padrão do erro de 20 é 0.001063834490698559
# O desvio padrão da segunda derivada de 20 é 0.0007126582010673278
# A média de erros de 21 é -0.0006974310150996449
# A média da segunda derivada de 21 é -5.003168570486748e-05
# O desvio padrão do erro de 21 é 0.0011247198158304624
# O desvio padrão da segunda derivada de 21 é 0.0009179508659548452
# A média de erros de 22 é 0.003483201352215529
# A média da segunda derivada de 22 é 2.1079738545130908e-05
# O desvio padrão do erro de 22 é 0.0008800328177610902
# O desvio padrão da segunda derivada de 22 é 0.0008966255089744964
# A média de erros de 23 é -0.00031721374400483024
# A média da segunda derivada de 23 é 1.098420167679939e-08
# O desvio padrão do erro de 23 é 0.0006134059399644253
# O desvio padrão da segunda derivada de 23 é 0.0004904311727268087
# A média de erros de 24 é 0.0048079097350656975
# A média da segunda derivada de 24 é 2.605241301248363e-05
# O desvio padrão do erro de 24 é 0.0008732800445571247
# O desvio padrão da segunda derivada de 24 é 0.0012393746817557032
# A média de erros de 25 é 0.0022740972024253214
# A média da segunda derivada de 25 é 7.110756680947158e-06
# O desvio padrão do erro de 25 é 0.00098158963875105
# O desvio padrão da segunda derivada de 25 é 0.00048145850466676816
# A média de erros de 26 é -0.0019603690377657692
# A média da segunda derivada de 26 é -3.3739412062453796e-05
# O desvio padrão do erro de 26 é 0.001063941583155503
# O desvio padrão da segunda derivada de 26 é 0.0006380418021303388
# A média de erros de 27 é -0.0017954820014506251
# A média da segunda derivada de 27 é -1.2421135112167908e-06
# O desvio padrão do erro de 27 é 0.0008582042445511676
# O desvio padrão da segunda derivada de 27 é 0.0010001098817350913
# A média de erros de 28 é 0.001312252638526797
# A média da segunda derivada de 28 é 3.4677820287047936e-05
# O desvio padrão do erro de 28 é 0.0008297441461315333
# O desvio padrão da segunda derivada de 28 é 0.0011560968577782468
# A média de erros de 29 é -0.00926509909127329
# A média da segunda derivada de 29 é 6.165565604661972e-05
# O desvio padrão do erro de 29 é 0.0013907370938373322
# O desvio padrão da segunda derivada de 29 é 0.0007265428567164164
# A média de erros de 30 é -0.002856002599926907
# A média da segunda derivada de 30 é -2.8331938418000686e-05
# O desvio padrão do erro de 30 é 0.0011507406129914455
# O desvio padrão da segunda derivada de 30 é 0.0006481158234395716
# A média de erros de 31 é 0.0009090272467686463
# A média da segunda derivada de 31 é -8.816757739056185e-05
# O desvio padrão do erro de 31 é 0.0017904508870273189
# O desvio padrão da segunda derivada de 31 é 0.0008468479257349385
# A média de erros de 32 é -0.00017274897780544566
# A média da segunda derivada de 32 é 5.3525199703559435e-05
# O desvio padrão do erro de 32 é 0.004207013428018623
# O desvio padrão da segunda derivada de 32 é 0.0007136445566738216
# A média de erros de 33 é -0.0016725032532885545
# A média da segunda derivada de 33 é -3.595690921971564e-05
# O desvio padrão do erro de 33 é 0.0013198945598639452
# O desvio padrão da segunda derivada de 33 é 0.0006495315318078871
# A média de erros de 34 é -0.0011118612316888094
# A média da segunda derivada de 34 é -5.397379245827461e-05
# O desvio padrão do erro de 34 é 0.0018129668369189415
# O desvio padrão da segunda derivada de 34 é 0.00088236470718283
# A média de erros de 35 é -0.0024117829126533543
# A média da segunda derivada de 35 é -3.927768093815915e-06
# O desvio padrão do erro de 35 é 0.000631762588614073
# O desvio padrão da segunda derivada de 35 é 0.0009191301328255009
# A média de erros de 36 é -0.004801374563299606
# A média da segunda derivada de 36 é -4.348824571725531e-05
# O desvio padrão do erro de 36 é 0.001628256635340901
# O desvio padrão da segunda derivada de 36 é 0.0006565100783499346
# A média de erros de 37 é -0.0019476696421333144
# A média da segunda derivada de 37 é -2.306056687495464e-06
# O desvio padrão do erro de 37 é 0.005039574193600941
# O desvio padrão da segunda derivada de 37 é 0.00096609043346237
# A média de erros de 38 é 0.0019774153558918105
# A média da segunda derivada de 38 é 2.1903300841745474e-05
# O desvio padrão do erro de 38 é 0.0008317669189745737
# O desvio padrão da segunda derivada de 38 é 0.0007692991633607754
# A média de erros de 39 é -0.015259474496516504
# A média da segunda derivada de 39 é -2.4596969393152054e-05
# O desvio padrão do erro de 39 é 0.000900069462707834
# O desvio padrão da segunda derivada de 39 é 0.0007185687986865182
# A média de erros de 40 é -0.010631403422549094
# A média da segunda derivada de 40 é -3.520700057594726e-05
# O desvio padrão do erro de 40 é 0.001078760856166651
# O desvio padrão da segunda derivada de 40 é 0.0003936651347187623
# A média de erros de 41 é 0.002458850169466991
# A média da segunda derivada de 41 é 0.0001006066279272967
# O desvio padrão do erro de 41 é 0.0018382808384228898
# O desvio padrão da segunda derivada de 41 é 0.0006803030332579984
# A média de erros de 42 é 0.004091423382018273
# A média da segunda derivada de 42 é -2.9206427119973512e-05
# O desvio padrão do erro de 42 é 0.0009475697320883959
# O desvio padrão da segunda derivada de 42 é 0.00035449543975975945
# A média de erros de 43 é 0.007649576754530139
# A média da segunda derivada de 43 é 3.376324086574376e-05
# O desvio padrão do erro de 43 é 0.0009259502076485552
# O desvio padrão da segunda derivada de 43 é 0.0005666682860693606
# A média de erros de 44 é -0.015163915778901211
# A média da segunda derivada de 44 é 2.012989939393721e-05
# O desvio padrão do erro de 44 é 0.0010670907162494544
# O desvio padrão da segunda derivada de 44 é 0.0005692617393988544
# A média de erros de 45 é -0.003850358757093523
# A média da segunda derivada de 45 é -5.3852530604450535e-06
# O desvio padrão do erro de 45 é 0.009307468552298056
# O desvio padrão da segunda derivada de 45 é 0.001142028728359932
# A média de erros de 46 é 0.008474062243882025
# A média da segunda derivada de 46 é -1.0049823400862167e-05
# O desvio padrão do erro de 46 é 0.0015391475231199272
# O desvio padrão da segunda derivada de 46 é 0.0008909553308101577
# A média de erros de 47 é -0.0014042386557129127
# A média da segunda derivada de 47 é -2.7790327457765483e-05
# O desvio padrão do erro de 47 é 0.0008762454914749345
# O desvio padrão da segunda derivada de 47 é 0.00035419624012959517
# A média de erros de 48 é 0.00019817602157060817
# A média da segunda derivada de 48 é -1.3982616282363753e-05
# O desvio padrão do erro de 48 é 0.0013044506457213821
# O desvio padrão da segunda derivada de 48 é 0.0008069262025950536
# A média de erros de 49 é -0.0020871621728811634
# A média da segunda derivada de 49 é 1.4539172276523916e-05
# O desvio padrão do erro de 49 é 0.0010666486128894782
# O desvio padrão da segunda derivada de 49 é 0.0009360633485905815
